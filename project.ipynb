# %%
import pandas as pd
from pycaret.classification import (
    setup,
    compare_models,
    evaluate_model,
    finalize_model,
    save_model,
    predict_model,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 from pycaret.classification import (
#       3     setup,
#       4     compare_models,
#    (...)
#       8     predict_model,
#       9 )
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv(r"C:\Users\Shivam.Singhal\Downloads\archive (6)\bots_vs_users.csv")

# %%
from pycaret.classification import setup

clf_setup = setup(
    data=df, 
    target='target', 
    session_id=123, 
    verbose=True, 
    preprocess=True
)
# Out:
# <style type="text/css">
# #T_ff22d_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ff22d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff22d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ff22d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff22d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff22d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ff22d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_ff22d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ff22d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ff22d_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_ff22d_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_0dfb7 th {
#   text-align: left;
# }
# ...

# %%
 evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
  # 5. Make predictions on the same data (for demonstration)
predictions = predict_model(best_model, data=df)
print(predictions[['prediction_label', 'prediction_score']])
# Out:
# <style type="text/css">
# </style>
# <table id="T_e54bd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e54bd_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e54bd_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e54bd_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e54bd_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e54bd_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e54bd_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e54bd_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e54bd_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e54bd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e54bd_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
# ...

# %%
  # 6. Save the model (optional)
save_model(best_model, 'best_pycaret_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['posts_count', 'avg_likes',
#                                               'links_ratio', 'hashtags_ratio',
#                                               'avg_keywords', 'avg_text_length',
#                                               'attachments_ratio',
#                                               'avg_comments', 'reposts_ratio',
#                                               'ads_ratio', 'avg_views',
#                                               'posting_frequency_days',
#                                               'phone_numbers_ratio',
#                                               'avg_text_uniqueness'],
#                                      transfor...
#                   RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
# ...
